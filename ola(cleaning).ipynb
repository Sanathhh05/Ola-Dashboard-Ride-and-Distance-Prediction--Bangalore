# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\CLG work\Projects\Ola Dashboard\Bookings_ola.csv")
df.head()
# Out:
#                   Date      Time     Booking_ID        Booking_Status  \
# 0  2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1  2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2  2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3   2024-07-22 3:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4   2024-07-02 9:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  ...  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN  ...
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0  ...
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0  ...
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN  ...
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0  ...
#
#        Canceled_Rides_by_Driver Incomplete_Rides Incomplete_Rides_Reason  \
# ...

# %%
df.shape
# Out:
# (103024, 21)

# %%
df.describe()
# Out:
#               V_TAT         C_TAT  Booking_Value  Ride_Distance  \
# count  44271.000000  44271.000000   71201.000000   71201.000000
# mean     171.323620     84.955275     548.233901      14.206598
# std       80.682293     35.959016     535.399324      15.778237
# min       35.000000     25.000000     100.000000       0.000000
# 25%       98.000000     55.000000     242.000000       0.000000
# 50%      168.000000     85.000000     385.000000       8.000000
# 75%      238.000000    115.000000     622.000000      27.000000
# max      308.000000    145.000000    2999.000000      49.000000
#
#        Driver_Ratings  Customer_Rating  Unnamed: 20
# count    44271.000000     44271.000000          0.0
# mean         3.997994         3.997145          NaN
# std          0.577948         0.578574          NaN
# min          3.000000         3.000000          NaN
# 25%          3.500000         3.500000          NaN
# 50%          4.000000         4.000000          NaN
# ...

# %%
df['Unnamed: 20'].unique()
# Out:
# array([nan])

# %%
df.drop('Unnamed: 20',axis=1,inplace=True)

# %%
df['Booking_Value'].sum()
# Out:
# np.float64(39034802.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        71201 non-null  object
#  1   Time                        71201 non-null  object
#  2   Booking_ID                  71201 non-null  object
#  3   Booking_Status              71201 non-null  object
#  4   Customer_ID                 71201 non-null  object
#  5   Vehicle_Type                71201 non-null  object
#  6   Pickup_Location             71201 non-null  object
#  7   Drop_Location               71201 non-null  object
#  8   V_TAT                       44271 non-null  float64
#  9   C_TAT                       44271 non-null  float64
#  10  Canceled_Rides_by_Customer  7214 non-null   object
#  11  Canceled_Rides_by_Driver    12728 non-null  object
#  12  Incomplete_Rides            44271 non-null  object
# ...

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (71202, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71202 entries, 0 to 71201
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        71201 non-null  object
#  1   Time                        71201 non-null  object
#  2   Booking_ID                  71201 non-null  object
#  3   Booking_Status              71201 non-null  object
#  4   Customer_ID                 71201 non-null  object
#  5   Vehicle_Type                71201 non-null  object
#  6   Pickup_Location             71201 non-null  object
#  7   Drop_Location               71201 non-null  object
#  8   V_TAT                       44271 non-null  float64
#  9   C_TAT                       44271 non-null  float64
#  10  Canceled_Rides_by_Customer  7214 non-null   object
#  11  Canceled_Rides_by_Driver    12728 non-null  object
#  12  Incomplete_Rides            44271 non-null  object
# ...

# %%
df1=df.copy()
df1.drop(['Date','Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
       'Vehicle_Type','Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
       'Incomplete_Rides', 'Incomplete_Rides_Reason','Payment_Method','Driver_Ratings', 'Customer_Rating',
       'Vehicle Images'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images'],
#       dtype='object')

# %%
df1
# Out:
#             Pickup_Location         Drop_Location  V_TAT  C_TAT  \
# 0               Tumkur Road              RT Nagar    NaN    NaN
# 1               Magadi Road               Varthur  203.0   30.0
# 2             Sahakar Nagar               Varthur  238.0  130.0
# 3                HSR Layout           Vijayanagar    NaN    NaN
# 4               Rajajinagar           Chamarajpet  252.0   80.0
# ...                     ...                   ...    ...    ...
# 71197       Electronic City               Varthur   49.0   30.0
# 71198         Sahakar Nagar  Rajarajeshwari Nagar    NaN    NaN
# 71199  Rajarajeshwari Nagar       Electronic City    NaN    NaN
# 71200            BTM Layout         Sahakar Nagar  217.0   25.0
# 71201                   NaN                   NaN    NaN    NaN
#
#        Booking_Value  Ride_Distance
# 0              444.0            0.0
# 1              158.0           13.0
# 2              386.0           40.0
# 3              384.0            0.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71202 entries, 0 to 71201
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pickup_Location  71201 non-null  object
#  1   Drop_Location    71201 non-null  object
#  2   V_TAT            44271 non-null  float64
#  3   C_TAT            44271 non-null  float64
#  4   Booking_Value    71201 non-null  float64
#  5   Ride_Distance    71201 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 3.8+ MB

# %%
df1.drop(['V_TAT', 'C_TAT'],axis=1)
# Out:
#             Pickup_Location         Drop_Location  Booking_Value  \
# 0               Tumkur Road              RT Nagar          444.0
# 1               Magadi Road               Varthur          158.0
# 2             Sahakar Nagar               Varthur          386.0
# 3                HSR Layout           Vijayanagar          384.0
# 4               Rajajinagar           Chamarajpet          822.0
# ...                     ...                   ...            ...
# 71197       Electronic City               Varthur          154.0
# 71198         Sahakar Nagar  Rajarajeshwari Nagar          447.0
# 71199  Rajarajeshwari Nagar       Electronic City          833.0
# 71200            BTM Layout         Sahakar Nagar          453.0
# 71201                   NaN                   NaN            NaN
#
#        Ride_Distance
# 0                0.0
# 1               13.0
# 2               40.0
# 3                0.0
# 4               45.0
# ...              ...
# 71197           28.0
# ...

# %%
df1.dropna(subset=['V_TAT','C_TAT'],inplace=True)

# %%
df1
# Out:
#        Pickup_Location  Drop_Location  V_TAT  C_TAT  Booking_Value  \
# 1          Magadi Road        Varthur  203.0   30.0          158.0
# 2        Sahakar Nagar        Varthur  238.0  130.0          386.0
# 4          Rajajinagar    Chamarajpet  252.0   80.0          822.0
# 5             Kadugodi    Vijayanagar  231.0   90.0          173.0
# 6          Tumkur Road     Whitefield  133.0   40.0          140.0
# ...                ...            ...    ...    ...            ...
# 71193      Indiranagar    Frazer Town   56.0   55.0         1460.0
# 71194      Mysore Road         Peenya  119.0  140.0          203.0
# 71196      Rajajinagar  Sarjapur Road  126.0   40.0          325.0
# 71197  Electronic City        Varthur   49.0   30.0          154.0
# 71200       BTM Layout  Sahakar Nagar  217.0   25.0          453.0
#
#        Ride_Distance
# 1               13.0
# 2               40.0
# 4               45.0
# 5               41.0
# 6               49.0
# ...              ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44271 entries, 1 to 71200
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pickup_Location  44271 non-null  object
#  1   Drop_Location    44271 non-null  object
#  2   V_TAT            44271 non-null  float64
#  3   C_TAT            44271 non-null  float64
#  4   Booking_Value    44271 non-null  float64
#  5   Ride_Distance    44271 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 2.4+ MB

# %%
df1['Pickup_Location'].value_counts()
# Out:
# Pickup_Location
# Indiranagar             939
# Banashankari            938
# Cox Town                935
# Yeshwanthpur            934
# Electronic City         925
# Mysore Road             923
# KR Puram                921
# Ramamurthy Nagar        918
# Koramangala             914
# Hennur                  912
# BTM Layout              911
# Magadi Road             909
# Shivajinagar            906
# Frazer Town             906
# MG Road                 905
# Nagarbhavi              904
# RT Nagar                903
# Malleshwaram            901
# Tumkur Road             899
# Jayanagar               897
# Ulsoor                  893
# Kammanahalli            891
# Rajarajeshwari Nagar    887
# Sahakar Nagar           886
# Hebbal                  885
# Richmond Town           884
# Basavanagudi            883
# HSR Layout              881
# Peenya                  879
# Kengeri                 875
# Kadugodi                875
# Yelahanka               874
# ...

# %%
print('The Sum of Booking value of the month September 2021 is :',df1['Booking_Value'].sum())
# Out:
# The Sum of Booking value of the month September 2021 is : 24216619.0

# %%
df1
# Out:
#        Pickup_Location  Drop_Location  V_TAT  C_TAT  Booking_Value  \
# 0          Magadi Road        Varthur  203.0   30.0          158.0
# 1        Sahakar Nagar        Varthur  238.0  130.0          386.0
# 2          Rajajinagar    Chamarajpet  252.0   80.0          822.0
# 3             Kadugodi    Vijayanagar  231.0   90.0          173.0
# 4          Tumkur Road     Whitefield  133.0   40.0          140.0
# ...                ...            ...    ...    ...            ...
# 44266      Indiranagar    Frazer Town   56.0   55.0         1460.0
# 44267      Mysore Road         Peenya  119.0  140.0          203.0
# 44268      Rajajinagar  Sarjapur Road  126.0   40.0          325.0
# 44269  Electronic City        Varthur   49.0   30.0          154.0
# 44270       BTM Layout  Sahakar Nagar  217.0   25.0          453.0
#
#        Ride_Distance
# 0               13.0
# 1               40.0
# 2               45.0
# 3               41.0
# 4               49.0
# ...              ...
# ...

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df1.to_csv('cleaned_olaSet.csv',index=False)

# %%
df3=df.copy()
df3
# Out:
#                       Date      Time     Booking_ID        Booking_Status  \
# 0      2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1      2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2      2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3       2024-07-22 3:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4       2024-07-02 9:02:00  09:02:00  CNR1797421769               Success
# ...                    ...       ...            ...                   ...
# 71197   2024-07-16 5:02:00  05:02:00  CNR3906366271               Success
# 71198  2024-07-03 22:14:00  22:14:00  CNR4789445170  Canceled by Customer
# 71199  2024-07-29 12:17:00  12:17:00  CNR5806198441    Canceled by Driver
# 71200  2024-07-19 21:38:00  21:38:00  CNR4531167950               Success
# 71201                  NaN       NaN            NaN                   NaN
#
#       Customer_ID Vehicle_Type       Pickup_Location         Drop_Location  \
# ...

# %%
df3.drop(['Date','Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
       'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
       'Incomplete_Rides', 'Incomplete_Rides_Reason','Payment_Method','Driver_Ratings', 'Customer_Rating',
       'Vehicle Images'],axis=1,inplace=True)

# %%
df3.head()
# Out:
#   Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  Booking_Value  \
# 0  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN          444.0
# 1         Bike     Magadi Road       Varthur  203.0   30.0          158.0
# 2    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0          386.0
# 3        eBike      HSR Layout   Vijayanagar    NaN    NaN          384.0
# 4         Mini     Rajajinagar   Chamarajpet  252.0   80.0          822.0
#
#    Ride_Distance
# 0            0.0
# 1           13.0
# 2           40.0
# 3            0.0
# 4           45.0

# %%
df3.dropna(subset=['V_TAT', 'C_TAT'],inplace=True)

# %%
df3
# Out:
#       Vehicle_Type  Pickup_Location  Drop_Location  V_TAT  C_TAT  \
# 1             Bike      Magadi Road        Varthur  203.0   30.0
# 2        Prime SUV    Sahakar Nagar        Varthur  238.0  130.0
# 4             Mini      Rajajinagar    Chamarajpet  252.0   80.0
# 5             Mini         Kadugodi    Vijayanagar  231.0   90.0
# 6             Bike      Tumkur Road     Whitefield  133.0   40.0
# ...            ...              ...            ...    ...    ...
# 71193   Prime Plus      Indiranagar    Frazer Town   56.0   55.0
# 71194         Bike      Mysore Road         Peenya  119.0  140.0
# 71196         Auto      Rajajinagar  Sarjapur Road  126.0   40.0
# 71197   Prime Plus  Electronic City        Varthur   49.0   30.0
# 71200    Prime SUV       BTM Layout  Sahakar Nagar  217.0   25.0
#
#        Booking_Value  Ride_Distance
# 1              158.0           13.0
# 2              386.0           40.0
# 4              822.0           45.0
# 5              173.0           41.0
# ...

# %%
df3.reset_index(drop=True,inplace=True)

# %%
df3.to_csv('clean_ola.csv',index=False)
